# %% [markdown]
# # Cleared Outputs

# %% [markdown]
# # Modified Title

# %% [markdown]
# ## Section 2

# %%
new_cell = 999

# %%
y = x * 2

# %%
print(y)

# %% [markdown]
# ## Markdown Cell

# %% [raw]
# Raw cell content
