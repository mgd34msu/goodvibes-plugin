# %% [markdown]
# # Sample Notebook
# This is a test notebook for E2E testing.

# %%
import math

def circle_area(r):
    return math.pi * r ** 2

print(circle_area(5))
# Out:
# 78.53981633974483

# %%
data = [1, 2, 3, 4, 5]
total = sum(data)
mean = total / len(data)
print(f'Mean: {mean}')
# Out:
# Mean: 3.0

# %% [markdown]
# ## Results
# The calculations above demonstrate basic math operations.

# %% [raw]
# Raw cell content for testing.
# This should be preserved as-is.
